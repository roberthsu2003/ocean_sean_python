# %% [markdown]
# <a href="https://colab.research.google.com/github/roberthsu2003/__ocean_sean_python__/blob/main/lesson2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = 10
n = n + 5
n
# Out:
# 15

# %%
# 複合指定運算子

m = 10
m += 5
m *= 10
m
# Out:
# 150

# %%
"我的半徑:" + str(5)
# Out:
# '我的半徑:5'

# %%
# 字串插補
f"我的半徑:{5}"
# Out:
# '我的半徑:5'

# %%
n = 5
m = 15
print(f"我的n={n},我的m={m}")
# Out:
# 我的n=5,我的m=15

# %%
import math

a = float(input("請輸入對邊:"))
b = float(input("請輸入鄰邊:"))

c = math.sqrt(a ** 2 + b ** 2)

print(f"對邊是{a},鄰邊是{b},斜邊是{c}")
# Out:
# 請輸入對邊:12
# 請輸入鄰邊:18
# 對邊是12.0,鄰邊是18.0,斜邊是21.633307652783937
