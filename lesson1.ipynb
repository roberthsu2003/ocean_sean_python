# %% [markdown]
# <a href="https://colab.research.google.com/github/roberthsu2003/ocean_sean_python/blob/main/lesson1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello! Python")
# Out:
# Hello! Python

# %% [markdown]
# **這是文字區塊**

# %%
print("Hello! I am Robert")
# Out:
# Hello! I am Robert

# %%
5 * 5
1024 * 1024
# Out:
# 1048576

# %%
5 * 5
1024 * 1024
# Out:
# 1048576

# %%
10 * 2345
# Out:
# 23450

# %% [markdown]
# 運算式(expression)-> 會傳出值
# 敘述式(statement) -> 不會傳出值

# %% [markdown]
# ## 數學運算子有那些?
#
# ```
# +
# -
# *
# /
# //
# %
# **
# ```
#
# > 全部都是2元運算子

# %% [markdown]
# 運算元和運算子之間,可以有多個空隔

# %%
5 + 8
90 - 10
4 * 7
7 / 2
7 // 2
7 % 2
3 ** 4
99 ** 99
# Out:
# 369729637649726772657187905628805440595668764281741102430259972423552570455277523421410650010128232727940978889548326540119429996769494359451621570193644014418071060667659301384999779999159200499899

# %% [markdown]
# **有關於運算元**
#
# 5 -> 整數(int)
# 5.0 -> 浮點數(float)
# "5" -> 文字(str)
# '5.0' -> 文字(str)
#
# ## python內建的函式
# - print()

# %%
print("print是一個內建function")
print(5 + 8)
print(90 - 10)
print(4 * 7)
print(7 / 2)
print(7 // 2)
print(7 % 2)
print(3 ** 4)
# Out:
# print是一個內建function
# 13
# 80
# 28
# 3.5
# 3
# 1
# 81
