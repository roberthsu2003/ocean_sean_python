# %%
student1:list[int] = [78, 92, 67]
student1[0]
student1[1]
student1[2]
student1[-1]
student1[-2]
student1[-3]
# Out:
# 78

# %%
# 基本語法
empty_list:list = []
numbers:list[int] = [1, 2, 3, 4, 5]
mixed_data:list[any] = [1, 'Python', 3.14, True]

# 使用 list() 函數
another_empty_list:list = list()
string_to_list:list[str] = list('Python')  # ['P', 'y', 't', 'h', 'o', 'n']
range_to_list:list = list(range(1, 6))  # [1, 2, 3, 4, 5]

# 從其他資料結構轉換
tuple_to_list:list[str] = list(('a', 'b', 'c'))  # ['a', 'b', 'c']

# %%
data = ['H', 'e', 'l', 'l', 'o', 'W', 'o', 'r', 'l', 'd']

print(data[2:])     # ['l', 'l', 'o', 'W', 'o', 'r', 'l', 'd']
print(data[:3])     # ['H', 'e', 'l']
print(data[3:5])    # ['l', 'l']
print(data[::2])    # ['H', 'l', 'o', 'o', 'l']
print(data[::-1])   # ['d', 'l', 'r', 'o', 'W', 'o', 'l', 'l', 'e', 'H']
# Out:
# ['l', 'l', 'o', 'W', 'o', 'r', 'l', 'd']
# ['H', 'e', 'l']
# ['l', 'o']
# ['H', 'l', 'o', 'o', 'l']
# ['d', 'l', 'r', 'o', 'W', 'o', 'l', 'l', 'e', 'H']

# %%
fruits:list[str] = ['apple', 'banana']
fruits.append("orange")
# extend() - 擴展多個元素
fruits.extend(['grape', 'kiwi'])
print(fruits)  # ['apple', 'banana', 'orange', 'grape', 'kiwi']

# insert() - 在指定位置插入元素
fruits.insert(1, 'mango')
print(fruits)  # ['apple', 'mango', 'banana', 'orange', 'grape', 'kiwi']

# 使用 + 運算符
more_fruits = fruits + ['pear', 'peach']
print(more_fruits)
# Out:
# ['apple', 'banana', 'orange', 'grape', 'kiwi']
# ['apple', 'mango', 'banana', 'orange', 'grape', 'kiwi']
# ['apple', 'mango', 'banana', 'orange', 'grape', 'kiwi', 'pear', 'peach']
