# %%
# tuple

empty_tuple = ()
coordinates:tuple = (10, 20)
#scoordinates[1] = 30

# %%
5, 7, 9
# Out:
# (5, 7, 9)

# %%
#tuple的拆解法
first, second, third = 5, 7, 9
print(first, second, third)
# Out:
# 5 7 9
