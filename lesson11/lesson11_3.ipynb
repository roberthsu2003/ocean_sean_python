# %%
#dictionary
codes:dict[str,str] = {"tw":"Taiwan", 
                       "jp":"Japan", 
                       'hk':"Hong Kong"}
print(codes["hk"])
print(codes["jp"])
print(codes["tw"])
# Out:
# Hong Kong
# Japan
# Taiwan
