# %%
count = 1

while count <= 5:
    print(count)
    count += 1
print("應用程式結束了!")
# Out:
# 1
# 2
# 3
# 4
# 5
# 應用程式結束了!

# %%
# 小美是一位教師，請你以while迴圈方式為小美設計一個輸入成績的程式，如果輸入負數表示成績輸入結束，在輸入成績結束後顯示班上總成績及平均成績。
score = 0
num = 0
sum = 0
while True:
    score = int(input("請輸入學生成績:"))    
    if score <= -1:
        break
    num += 1
    sum += score
print(f"學生總分:{sum},學生平均是{round(sum/num,ndigits=2)}")
# Out:
# 學生總分:242,學生平均是80.67

# %%
# 顯示:
# 奇數輸出平方
# 偶數不做任何動作
# 'q'要離開

while (True):
    value = input("請輸入整數,輸入(q)離開:")
    if value == 'q':
        break
    valueInt = int(value)
    if valueInt % 2 == 1:
        print(f"{valueInt}的平方是{valueInt ** 2}")
    else:
        print("偶數不做事")
        continue
    print("還在迴圈內")
print("跳出迴圈")
# Out:
# 3的平方是9
# 還有迴圈內
# 5的平方是25
# 還有迴圈內
# 7的平方是49
# 還有迴圈內
# 偶數不做事
# 還有迴圈內
# 跳出迴圈
